# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
from scipy.stats import norm
from string import ascii_letters

# %%
data = pd.read_csv(r"E:\\Data\atta\\Python_visulization\\practice\\SeabornLibrary\\Lineplot\\tips.csv")
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
x = data['sex']
y = data['tip']
sns.barplot(x,y,data = data,)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.legend('day')
x = data['day']
y = data['total_bill']
sns.barplot(x,y,data = data,)
plt.show()

# %%
plt.figure(figsize=(16,9))
#plt.legend('day')
sns.barplot(x='day',y = 'total_bill',data = data,hue=data.sex)
plt.show()

# %%
plt.figure(figsize=(16,9))
#plt.legend('day')
sns.barplot(x='day',y = 'size',data = data,hue=data.sex)
plt.show()

# %%
days = ['thur','fri','sat','sun']
plt.figure(figsize=(16,9))
plt.legend('day')
sns.barplot(x='day',y = 'size',data = data, hue=data.sex)
plt.show()

# %%
plt.figure(figsize=(16,9))
plt.legend('day')
sns.barplot(x='day',y = 'size',data = data, hue=data.sex)
plt.show()

# %%
plt.figure(figsize=(16,9))
plt.legend('day')
sns.barplot(x='day',y = 'size',data = data, hue=data.sex,estimator=np.max,ci=90,n_boot=10)
plt.show()

# %%
plt.figure(figsize=(16,9))
plt.legend('day')
sns.barplot(x='day',y = 'size',data = data, hue=data.sex,estimator=np.max,ci=90,n_boot=10,
           orient='v',capsize=0.09)
plt.show()

# %%
plt.figure(figsize=(16,9))
plt.legend('day')
sns.barplot(y='day',x= 'size',data = data, hue=data.sex,estimator=np.max,ci=90,n_boot=10,color='green',palette='winter',
           saturation=0.09,errcolor='0.01')
plt.show()

# %%
plt.figure(figsize=(16,9))
plt.legend('day')
sns.barplot(y='day',x= 'size',data = data, hue=data.sex,estimator=np.max,ci=90,n_boot=10,color='green',palette='winter',
           saturation=0.09,errwidth='10')
plt.show()

# %%
plt.legend('day')
sns.barplot(x='day',y = 'size',data = data, hue=data.sex,dodge=False)
plt.show()

# %%
sns.set()
kwargs = {'alpha':0.8,'linestyle':'--','linewidth':1.9,'edgecolor':'b'}
plt.title("bar plot")
sns.barplot(x='day',y = 'size',data = data, **kwargs)
plt.show()

# %%
sns.barplot(x='day',y = 'total_bill',data = data, hue=data.sex,alpha = 0.99,)
plt.title("bar plot of tips dataset")
plt.xlabel('Day')
plt.ylabel('Totl bill')
plt.show()
