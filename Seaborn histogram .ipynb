# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
from scipy.stats import norm
from string import ascii_letters

# %%
data = pd.read_csv(r"E:\\Data\atta\\Python_visulization\\practice\\SeabornLibrary\\Lineplot\\tips.csv")

# %%
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
y = data['size']
sns.distplot(y)
plt.show()

# %%
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.distplot(data['total_bill'])
plt.show()

# %%
sns.distplot(data['tip'],vertical=False,color="y",rug=True, rug_kws={"color": "g"}, bins =10)
#sns.distplot(data['sex'])
plt.show()

# %%
sns.distplot(data['total_bill'],hist = False)
plt.show()

# %%
sns.distplot(data['total_bill'],kde = False,rug=True,fit=norm)
plt.show()

# %%
sns.distplot(data['total_bill'],fit=norm,kde = False,)
plt.show()Tr

# %%
sns.distplot(data['total_bill'],hist = True,color='r',norm_hist=False,axlabel='Total bill',label="total_bill")
plt.legend()
plt.title('Histogram',color = 'r', fontweight='bold',fontsize = "20")
plt.show()

# %%
plt.figure(figsize=(16,9))
sns.set(style='dark')
sns.distplot(data['total_bill'])
plt.show()

# %%
#data.total_bill.sort_values()
bins = [1,5,10,15, 20, 25, 30, 35, 40, 45, 50, 55,60]
plt.figure(figsize=(16,9))
sns.set(style='dark')
sns.distplot(data['total_bill'],axlabel='Total bill')
plt.xticks(bins)
plt.show()

# %%
plt.figure(figsize=(16,9))
sns.set(style='dark')
sns.distplot(data['total_bill'],axlabel='Total bill',
            hist_kws={'color':'#1A012D','edgecolor':'#BA2322','Linewidth':5,'linestyle':'--','alpha':0.9})
plt.show()

# %%
plt.figure(figsize=(16,9))
sns.set(style='dark')
sns.distplot(data['total_bill'],axlabel='Total bill',
            hist_kws={'color':'#1A012D','edgecolor':'#BA2322','Linewidth':5,'linestyle':'--','alpha':0.9},
            kde_kws={'color':'#53A6DC','Linewidth':3,'linestyle':'--','alpha':0.9},
            rug=True,
            rug_kws={'color':'#53A6DC','Linewidth':3,'linestyle':'--','alpha':0.9})
plt.show()

# %%
plt.figure(figsize=(16,9))
sns.set(style='dark')
sns.distplot(data['total_bill'],axlabel='Total bill',
            hist_kws={'color':'#1A012D','edgecolor':'#BA2322','Linewidth':5,'linestyle':'--','alpha':0.9},
            fit_kws={'color':'ffffff','edgecolor':'#BA2322','Linewidth':20,'linestyle':'--','alpha':0.1},
            rug=True,
            rug_kws={'color':'#53A6DC','Linewidth':3,'linestyle':'--','alpha':0.9})
plt.show()

# %%
plt.figure(figsize=(16,9))
sns.set(style='dark')
sns.distplot(data['total_bill'],axlabel='Total bill',
            hist_kws={'color':'#1A012D','edgecolor':'#BA2322','Linewidth':5,'linestyle':'--','alpha':0.9},
            fit_kws = {'color':'#1A012D','edgecolor':'#BA2322','Linewidth':5,'linestyle':'--','alpha':0.9},
            rug=True,
            rug_kws={'color':'#53A6DC','Linewidth':3,'linestyle':'--','alpha':0.9})
plt.show()
